# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("C:/Users/akanksha goel/OneDrive/Desktop/ml r/winequality-red.csv",sep=';')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
df.shape
# Out:
# (1599, 12)

# %%
X=df.drop('quality',axis=1)

# %%
X
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y=df['quality']

# %%
print(X.shape,y.shape)
# Out:
# (1599, 11) (1599,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

# %%
x_train_scaled = scaler.fit_transform(X)
XNew = pd.DataFrame(x_train_scaled)

# %%
X.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol'],
#       dtype='object')

# %%
XNew.columns=X.columns

# %%
XNew.head(2)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0       0.247788          0.397260          0.0        0.068493   0.106845
# 1       0.283186          0.520548          0.0        0.116438   0.143573
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0             0.140845              0.098940  0.567548  0.606299   0.137725
# 1             0.338028              0.215548  0.494126  0.362205   0.209581
#
#     alcohol
# 0  0.153846
# 1  0.215385

# %%
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1599, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(XNew,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (1279, 11)

# %%
X_test.shape
# Out:
# (320, 11)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn.metrics import mean_squared_error 
from math import sqrt

# %%
rmse_val = [] #to store rmse values for different k
for K in range(20):
    K = K+1
    model = KNeighborsRegressor(n_neighbors = K)
   
    model.fit(X_train, y_train)  #fit the model
    pred=model.predict(X_test) #make prediction on test set
    error = sqrt(mean_squared_error(y_test,pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.8023403267940606
# RMSE value for k=  2 is: 0.7169815199849994
# RMSE value for k=  3 is: 0.6874368657880114
# RMSE value for k=  4 is: 0.6605513795307675
# RMSE value for k=  5 is: 0.6526867548832288
# RMSE value for k=  6 is: 0.6577529086890371
# RMSE value for k=  7 is: 0.6533371945602963
# RMSE value for k=  8 is: 0.6602926079587745
# RMSE value for k=  9 is: 0.6547546897149372
# RMSE value for k=  10 is: 0.6508648093114269
# RMSE value for k=  11 is: 0.6482254862250755
# RMSE value for k=  12 is: 0.6445551868450745
# RMSE value for k=  13 is: 0.6467087818490715
# RMSE value for k=  14 is: 0.6476507782842886
# RMSE value for k=  15 is: 0.6502029597663247
# RMSE value for k=  16 is: 0.6485786743911643
# RMSE value for k=  17 is: 0.6502345198433007
# RMSE value for k=  18 is: 0.6479058740318213
# RMSE value for k=  19 is: 0.6445018368697888
# RMSE value for k=  20 is: 0.6448958249205837

# %%
#plotting the rmse values against k values
curve = pd.DataFrame(rmse_val) #elbow curve 
curve.plot()
curve
# Out:
#            0
# 0   0.802340
# 1   0.716982
# 2   0.687437
# 3   0.660551
# 4   0.652687
# 5   0.657753
# 6   0.653337
# 7   0.660293
# 8   0.654755
# 9   0.650865
# 10  0.648225
# 11  0.644555
# 12  0.646709
# 13  0.647651
# 14  0.650203
# 15  0.648579
# 16  0.650235
# 17  0.647906
# 18  0.644502
# 19  0.644896

# %%
pred = model.predict(X_test)

# %%
pred
# Out:
# array([6.65, 5.15, 5.5 , 5.5 , 5.35, 5.55, 6.6 , 6.65, 5.5 , 5.  , 5.55,
#        6.05, 5.85, 5.1 , 6.  , 5.5 , 6.55, 5.8 , 5.5 , 5.45, 5.45, 5.2 ,
#        5.75, 5.4 , 5.8 , 5.35, 5.05, 5.3 , 6.05, 5.3 , 6.4 , 5.7 , 5.2 ,
#        6.  , 5.45, 5.55, 6.05, 5.1 , 5.35, 5.8 , 5.45, 6.  , 6.35, 6.7 ,
#        5.7 , 4.95, 5.3 , 5.95, 5.5 , 6.6 , 5.9 , 6.05, 5.65, 5.2 , 5.35,
#        6.45, 5.7 , 5.35, 5.8 , 6.7 , 6.1 , 5.85, 6.5 , 5.5 , 5.3 , 5.25,
#        5.2 , 5.25, 5.85, 6.75, 5.4 , 5.9 , 5.6 , 5.3 , 6.15, 5.55, 5.65,
#        6.4 , 5.2 , 5.15, 5.15, 5.85, 5.65, 5.25, 6.3 , 5.9 , 5.7 , 5.15,
#        5.7 , 5.6 , 5.7 , 5.8 , 5.5 , 5.65, 5.85, 6.4 , 5.3 , 5.55, 5.35,
#        5.3 , 6.5 , 5.3 , 5.7 , 5.4 , 5.25, 6.7 , 5.2 , 5.2 , 5.55, 5.05,
#        5.6 , 5.95, 6.  , 6.2 , 5.45, 6.5 , 5.5 , 5.4 , 6.6 , 6.4 , 5.55,
#        6.9 , 5.95, 5.55, 5.5 , 6.4 , 5.7 , 5.25, 5.65, 5.15, 5.4 , 5.75,
#        5.35, 5.45, 5.2 , 5.6 , 6.25, 5.1 , 5.25, 5.3 , 5.45, 6.  , 5.05,
# ...
